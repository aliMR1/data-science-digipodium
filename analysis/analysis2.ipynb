# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
salary=pd.read_csv("Data Science Salary 2021 to 2023.csv")

# %%
salary.tail()
# Out:
#       work_year experience_level employment_type                  job_title  \
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
#       salary salary_currency  salary_in_usd company_location company_size
# 3756  130000             EUR         148261               DE            M
# 3757   80000             EUR          91237               AT            S
# 3758  190200             USD         190200               US            M
# 3759   40000             EUR          45618               HR            S
# 3760  412000             USD         412000               US            L

# %%
salary.sample()
# Out:
#       work_year experience_level employment_type      job_title  salary  \
# 1312       2023               SE              FT  Data Engineer  180000
#
#      salary_currency  salary_in_usd company_location company_size
# 1312             USD         180000               US            M

# %%
salary['job_title']
# Out:
# 0               Applied Scientist
# 1               Applied Scientist
# 2            Data Quality Analyst
# 3         Compliance Data Analyst
# 4               Applied Scientist
#                   ...
# 3756     Principal Data Scientist
# 3757               Data Scientist
# 3758         Data Science Manager
# 3759    Machine Learning Engineer
# 3760               Data Scientist
# Name: job_title, Length: 3761, dtype: object

# %%
salary.salary
# Out:
# 0       213660
# 1       130760
# 2       100000
# 3        30000
# 4       204620
#          ...
# 3756    130000
# 3757     80000
# 3758    190200
# 3759     40000
# 3760    412000
# Name: salary, Length: 3761, dtype: int64

# %%
cols=['salary','salary_currency','salary_in_usd']
salary[cols]
# Out:
#       salary salary_currency  salary_in_usd
# 0     213660             USD         213660
# 1     130760             USD         130760
# 2     100000             USD         100000
# 3      30000             USD          30000
# 4     204620             USD         204620
# ...      ...             ...            ...
# 3756  130000             EUR         148261
# 3757   80000             EUR          91237
# 3758  190200             USD         190200
# 3759   40000             EUR          45618
# 3760  412000             USD         412000
#
# [3761 rows x 3 columns]

# %%
salary.iloc[3224]
# Out:
# work_year                           2022
# experience_level                      SE
# employment_type                       FT
# job_title           Data Science Manager
# salary                            249260
# salary_currency                      USD
# salary_in_usd                     249260
# company_location                      US
# company_size                           M
# Name: 3224, dtype: object

# %%
salary.set_index('job_title',inplace=True)

# %%
salary.loc['Applied Scientist']
# Out:
#                    work_year experience_level employment_type  salary  \
# job_title
# Applied Scientist       2023               EN              FT  213660
# Applied Scientist       2023               EN              FT  130760
# Applied Scientist       2023               EN              FT  204620
# Applied Scientist       2023               EN              FT  110680
# Applied Scientist       2023               EN              FT  213660
# Applied Scientist       2023               EN              FT  130760
# Applied Scientist       2023               SE              FT  222200
# Applied Scientist       2023               SE              FT  136000
# Applied Scientist       2023               SE              FT  309400
# Applied Scientist       2023               SE              FT  159100
# Applied Scientist       2023               SE              FT  309400
# Applied Scientist       2023               SE              FT  159100
# ...

# %%
salary.loc['Applied Scientist','salary_in_usd'].plot(kind='area',figsize=(15,5))
# Out:
# <Axes: xlabel='job_title'>

# %%
salary.sort_index(ascending=False)
# Out:
#                                work_year experience_level employment_type  \
# job_title
# Staff Data Scientist                2021               SE              CT
# Staff Data Analyst                  2020               EX              FT
# Software Data Engineer              2023               SE              FL
# Software Data Engineer              2023               MI              FT
# Research Scientist                  2023               MI              FT
# ...                                  ...              ...             ...
# AI Developer                        2022               EN              FT
# 3D Computer Vision Researcher       2021               EN              FT
# 3D Computer Vision Researcher       2022               EN              FT
# 3D Computer Vision Researcher       2022               SE              FT
# 3D Computer Vision Researcher       2021               MI              PT
#
# ...

# %%
salary.sort_values(by='salary',ascending=False)
# Out:
#                                 work_year experience_level employment_type  \
# job_title
# Data Scientist                       2021               MI              FT
# Data Scientist                       2020               MI              FT
# BI Data Analyst                      2021               MI              FT
# ML Engineer                          2021               MI              FT
# Lead Machine Learning Engineer       2022               SE              FT
# ...                                   ...              ...             ...
# Product Data Scientist               2022               SE              FT
# Data Analyst                         2020               MI              FT
# Analytics Engineer                   2022               MI              CT
# Autonomous Vehicle Technician        2023               EN              FT
# AI Developer                         2022               EN              FT
#
# ...

# %%
salary[salary['company_location']=='IN']
# Out:
#                                     work_year experience_level  \
# job_title
# Data Engineer                            2023               EN
# Data Analyst                             2023               EN
# Data Analyst                             2023               EN
# Data Scientist                           2023               EN
# Data Scientist                           2023               EN
# Data Scientist                           2023               EN
# Applied Data Scientist                   2023               MI
# Data Scientist                           2023               MI
# Lead Data Analyst                        2023               MI
# Product Data Analyst                     2023               MI
# Head of Data Science                     2023               MI
# Data Analyst                             2023               SE
# AI Developer                             2022               EN
# Data Scientist                           2022               EN
# ...

# %%
salary[salary['salary']>300000]
# Out:
#                       work_year experience_level employment_type    salary  \
# job_title
# Data Engineer              2023               EN              FT   1400000
# Data Scientist             2023               EN              FT    800000
# Data Scientist             2023               EN              FT   1050000
# Data Scientist             2023               EN              FT   1060000
# Head of Data               2023               EX              FT    329500
# ...                         ...              ...             ...       ...
# Data Scientist             2020               MI              FT  11000000
# Data Scientist             2020               MI              FT   3000000
# Product Data Analyst       2020               MI              FT    450000
# Data Engineer              2020               SE              FT    720000
# Data Scientist             2020               SE              FT    412000
#
# ...

# %%
salary.describe()
# Out:
#          work_year        salary  salary_in_usd
# count  3761.000000  3.761000e+03    3761.000000
# mean   2022.374103  1.905999e+05  137555.178942
# std       0.691252  6.711457e+05   63022.267974
# min    2020.000000  6.000000e+03    5132.000000
# 25%    2022.000000  1.000000e+05   95000.000000
# 50%    2022.000000  1.375000e+05  135000.000000
# 75%    2023.000000  1.800000e+05  175000.000000
# max    2023.000000  3.040000e+07  450000.000000

# %%
 salary.describe(exclude=np.number)
# Out:
#        experience_level employment_type salary_currency company_location  \
# count              3761            3761            3761             3761
# unique                4               4              20               72
# top                  SE              FT             USD               US
# freq               2518            3724            3229             3045
#
#        company_size
# count          3761
# unique            3
# top               M
# freq           3157

# %%
salary[['salary','salary_in_usd']].agg(['mean','median']).T.plot(kind='bar')
# Out:
# <Axes: >

# %%
salary['company_location'].value_counts()
# Out:
# company_location
# US    3045
# GB     173
# CA      87
# ES      77
# IN      58
#       ...
# CR       1
# MA       1
# AM       1
# MK       1
# NZ       1
# Name: count, Length: 72, dtype: int64

# %%
salary['Total']=salary['salary'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ali\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\ali\miniconda3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ali\miniconda3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'salarysalary_in_usd'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
salary.head(1)
# Out:
#                    work_year experience_level employment_type  salary  \
# job_title
# Applied Scientist       2023               EN              FT  213660
#
#                   salary_currency  salary_in_usd company_location  \
# job_title
# Applied Scientist             USD         213660               US
#
#                   company_size      Total
# job_title
# Applied Scientist            L  716846172
